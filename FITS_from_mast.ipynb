# %% [markdown]
# # Скачивание FITS файлов

# %% [markdown]
# ## Вот с этого сайта
# Переходить не нужно, чисто для понимания, что используется база данных mast
#
# https://mast.stsci.edu/search/ui/#/hst

# %% [markdown]
# ### 1) target - Имя центрального объекта
# ### 2) radius - Выведутся все объекты, которые есть в каталоге, находящиеся на угловом расстояние в radius от объекта

# %%
from astroquery.mast import Observations

# Параметры запроса
target = "NGC 6888 "  # Имя объекта
radius = 5         # Радиус поиска в градусах (по умолчанию)

# Выполнение запроса
results = Observations.query_object(
    target,
    radius=radius,
    # radius_units не нужен - используется только градусы
    # select_cols можно указать, если нужны конкретные поля
)

print(results)

# %%
# Пустой запрос для получения структуры таблицы
empty_query = Observations.query_object("NGC 6888", radius=0.1)

# Вывести список всех параметров (столбцов)
print("Все доступные параметры:")
print(empty_query.columns)

# %% [markdown]
# ## Разбор параметров
# На Английском, потом на Русском

# %%
=== MAST Parameters (English) ===

◆ Основные метаданныe
+-----------------+---------------------------------------+
|    Parameter    |              Description              |
+-----------------+---------------------------------------+
|  obs_collection | Mission name (HST, JWST, Kepler etc.) |
|      obs_id     |         Observation unique ID         |
|    obs_title    |           Observation title           |
|   proposal_id   |               Program ID              |
|   proposal_pi   |         Principal Investigator        |
|  proposal_type  |    Program type (CAL/ENG/GTO/GUEST)   |
| sequence_number |      Observation sequence number      |
+-----------------+---------------------------------------+

◆ Целевой объект
+-----------------------+------------------------------------+
|       Parameter       |            Description             |
+-----------------------+------------------------------------+
|      target_name      |            Target name             |
| target_classification |       Object classification        |
|          s_ra         |       Right Ascension (deg)        |
|         s_dec         |         Declination (deg)          |
|        s_region       |      Observation area polygon      |
|        distance       | Angular distance from query center |
+-----------------------+------------------------------------+

◆ Инструменты
+-------------------+-----------------------------------+
|     Parameter     |            Description            |
+-------------------+-----------------------------------+
|  instrument_name  |  Instrument name (ACS, WFC3 etc.) |
|      filters      |   Filters used (comma-separated)  |
| wavelength_region | Wavelength range (UV/Optical/NIR) |
|       em_min      |      Minimum wavelength (nm)      |
|       em_max      |      Maximum wavelength (nm)      |
+-------------------+-----------------------------------+

◆ Временные параметры
+---------------+---------------------+
|   Parameter   |     Description     |
+---------------+---------------------+
|     t_min     |   Start time (MJD)  |
|     t_max     |    End time (MJD)   |
|   t_exptime   | Exposure time (sec) |
| t_obs_release |  Data release date  |
+---------------+---------------------+

◆ Доступ к данным
+-------------+--------------------+
|  Parameter  |    Description     |
+-------------+--------------------+
|   dataURL   |  Data access URL   |
|   jpegURL   | Preview image URL  |
| calib_level | Calibration level  |
|  dataRights | Data access rights |
+-------------+--------------------+

=== Параметры MAST (Русский) ===

◆ Основные метаданныe
+-----------------+-------------------------------------------+
|     Параметр    |                  Описание                 |
+-----------------+-------------------------------------------+
|  obs_collection | Название миссии (HST, JWST, Kepler и др.) |
|      obs_id     |    Уникальный идентификатор наблюдения    |
|    obs_title    |            Название наблюдения            |
|   proposal_id   |            ID научной программы           |
|   proposal_pi   |           Руководитель программы          |
|  proposal_type  |     Тип программы (CAL/ENG/GTO/GUEST)     |
| sequence_number |        Порядковый номер наблюдения        |
+-----------------+-------------------------------------------+

◆ Целевой объект
+-----------------------+------------------------------+
|        Параметр       |           Описание           |
+-----------------------+------------------------------+
|      target_name      |  Название целевого объекта   |
| target_classification |    Классификация объекта     |
|          s_ra         | Прямое восхождение (градусы) |
|         s_dec         |     Склонение (градусы)      |
|        s_region       |  Полигон области наблюдения  |
|        distance       | Угловое расстояние от центра |
+-----------------------+------------------------------+

◆ Инструменты
+-------------------+--------------------------+
|      Параметр     |         Описание         |
+-------------------+--------------------------+
|  instrument_name  |   Название инструмента   |
|      filters      |  Использованные фильтры  |
| wavelength_region |    Диапазон длин волн    |
|       em_min      | Минимальная длина волны  |
|       em_max      | Максимальная длина волны |
+-------------------+--------------------------+

◆ Временные параметры
+---------------+------------------------+
|    Параметр   |        Описание        |
+---------------+------------------------+
|     t_min     |      Время начала      |
|     t_max     |    Время окончания     |
|   t_exptime   |    Время экспозиции    |
| t_obs_release | Дата публикации данных |
+---------------+------------------------+

◆ Доступ к данным
+-------------+--------------------+
|   Параметр  |      Описание      |
+-------------+--------------------+
|   dataURL   |  Ссылка на данные  |
|   jpegURL   |  Ссылка на превью  |
| calib_level | Уровень калибровки |
|  dataRights |   Права доступа    |
+-------------+--------------------+

# %% [markdown]
# # Получение значений параметра
# Можно вывести любые параметры, можно сразу в несколько колонок.
#
# for obs in results[:100]  - это количество сколько выводить строчек

# %%
from astroquery.mast import Observations
from prettytable import PrettyTable
import textwrap  # Для переноса длинных строк

# Запрос данных
results = Observations.query_object("NGC 6888", radius=0.2)

# Настройка таблицы
table = PrettyTable()
table.field_names = ["ID", "Data URL"]
table.align["ID"] = "l"  # Выравнивание по левому краю
table.align["Data URL"] = "l"
table.max_width = 200  # Максимальная ширина таблицы
table._max_width = {"Data URL": 130}  # Особое ограничение для URL

# Заполнение таблицы с переносом длинных URL
for obs in results[:100]:  # Первые 10 результатов
    wrapped_url = textwrap.fill(obs['dataURL'], width=100) if obs['dataURL'] else "N/A"
    table.add_row([
        obs['obs_id'],
        wrapped_url
    ])

# Красивый вывод
print(table.get_string())
# Out:
# +------------------------------------------------------+--------------------------------------------------------------------------------------------------+
# | ID                                                   | Data URL                                                                                         |
# +------------------------------------------------------+--------------------------------------------------------------------------------------------------+
# | tess-s0014-1-1                                       | N/A                                                                                              |
# | tess-s0015-1-2                                       | N/A                                                                                              |
# | tess-s0041-1-1                                       | N/A                                                                                              |
# | tess-s0054-3-2                                       | N/A                                                                                              |
# | tess-s0055-3-1                                       | N/A                                                                                              |
# | tess-s0075-4-3                                       | N/A                                                                                              |
# | tess-s0081-3-2                                       | N/A                                                                                              |
# | tess-s0082-3-1                                       | N/A                                                                                              |
# | tess2021204101404-s0041-0000000312070919-0212-s      | mast:TESS/product/tess2021204101404-s0041-0000000312070919-0212-s_lc.fits                        |
# | tess2022190063128-s0054-0000000312070919-0227-s      | mast:TESS/product/tess2022190063128-s0054-0000000312070919-0227-s_lc.fits                        |
# | tess2022217014003-s0055-0000000312070919-0242-s      | mast:TESS/product/tess2022217014003-s0055-0000000312070919-0242-s_lc.fits                        |
# | tess2019198215352-s0014-0000000043299926-0150-s      | mast:TESS/product/tess2019198215352-s0014-0000000043299926-0150-s_lc.fits                        |
# | tess2019226182529-s0015-0000000043299926-0151-s      | mast:TESS/product/tess2019226182529-s0015-0000000043299926-0151-s_lc.fits                        |
# | tess2024030031500-s0075-0000000043299926-0270-a_fast | mast:TESS/product/tess2024030031500-s0075-0000000043299926-0270-a_fast-lc.fits                   |
# | tess2024030031500-s0075-0000000043299926-0270-s      | mast:TESS/product/tess2024030031500-s0075-0000000043299926-0270-s_lc.fits                        |
# | tess2024196212429-s0081-0000000043299926-0276-a_fast | mast:TESS/product/tess2024196212429-s0081-0000000043299926-0276-a_fast-lc.fits                   |
# | tess2024196212429-s0081-0000000043299926-0276-s      | mast:TESS/product/tess2024196212429-s0081-0000000043299926-0276-s_lc.fits                        |
# | tess2024223182411-s0082-0000000043299926-0278-a_fast | mast:TESS/product/tess2024223182411-s0082-0000000043299926-0278-a_fast-lc.fits                   |
# | tess2024223182411-s0082-0000000043299926-0278-s      | mast:TESS/product/tess2024223182411-s0082-0000000043299926-0278-s_lc.fits                        |
# | tess2022190063128-s0054-0000000043300086-0227-s      | mast:TESS/product/tess2022190063128-s0054-0000000043300086-0227-s_lc.fits                        |
# | tess2021204101404-s0041-0000000312072040-0212-s      | mast:TESS/product/tess2021204101404-s0041-0000000312072040-0212-s_lc.fits                        |
# | tess2022190063128-s0054-0000000312072040-0227-s      | mast:TESS/product/tess2022190063128-s0054-0000000312072040-0227-s_lc.fits                        |
# | tess2022217014003-s0055-0000000312072040-0242-s      | mast:TESS/product/tess2022217014003-s0055-0000000312072040-0242-s_lc.fits                        |
# | tess2024030031500-s0075-0000000312072040-0270-s      | mast:TESS/product/tess2024030031500-s0075-0000000312072040-0270-s_lc.fits                        |
# | tess2024196212429-s0081-0000000312072040-0276-s      | mast:TESS/product/tess2024196212429-s0081-0000000312072040-0276-s_lc.fits                        |
# | tess2024223182411-s0082-0000000312072040-0278-s      | mast:TESS/product/tess2024223182411-s0082-0000000312072040-0278-s_lc.fits                        |
# | sdss_apogee_apo25m_fl_2020_2m20124780+3813396        | mast:SDSS/apogee/apo25m/FL_2020/2M20124780+3813396/apStar-dr17-2M20124780+3813396.fits           |
# | rings.v3.skycell.2146.058.stk.g                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/058/rings.v3.skycell.2146.058.stk.g.unconv.fits |
# | rings.v3.skycell.2146.058.stk.i                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/058/rings.v3.skycell.2146.058.stk.i.unconv.fits |
# | rings.v3.skycell.2146.058.stk.r                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/058/rings.v3.skycell.2146.058.stk.r.unconv.fits |
# | rings.v3.skycell.2146.058.stk.y                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/058/rings.v3.skycell.2146.058.stk.y.unconv.fits |
# | rings.v3.skycell.2146.058.stk.z                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/058/rings.v3.skycell.2146.058.stk.z.unconv.fits |
# | rings.v3.skycell.2146.068.stk.g                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/068/rings.v3.skycell.2146.068.stk.g.unconv.fits |
# | rings.v3.skycell.2146.068.stk.i                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/068/rings.v3.skycell.2146.068.stk.i.unconv.fits |
# | rings.v3.skycell.2146.068.stk.r                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/068/rings.v3.skycell.2146.068.stk.r.unconv.fits |
# | rings.v3.skycell.2146.068.stk.y                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/068/rings.v3.skycell.2146.068.stk.y.unconv.fits |
# | rings.v3.skycell.2146.068.stk.z                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/068/rings.v3.skycell.2146.068.stk.z.unconv.fits |
# | rings.v3.skycell.2146.059.stk.g                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/059/rings.v3.skycell.2146.059.stk.g.unconv.fits |
# | rings.v3.skycell.2146.059.stk.i                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/059/rings.v3.skycell.2146.059.stk.i.unconv.fits |
# | rings.v3.skycell.2146.059.stk.r                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/059/rings.v3.skycell.2146.059.stk.r.unconv.fits |
# | rings.v3.skycell.2146.059.stk.y                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/059/rings.v3.skycell.2146.059.stk.y.unconv.fits |
# | rings.v3.skycell.2146.059.stk.z                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/059/rings.v3.skycell.2146.059.stk.z.unconv.fits |
# | rings.v3.skycell.2146.069.stk.g                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/069/rings.v3.skycell.2146.069.stk.g.unconv.fits |
# | rings.v3.skycell.2146.069.stk.i                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/069/rings.v3.skycell.2146.069.stk.i.unconv.fits |
# | rings.v3.skycell.2146.069.stk.r                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/069/rings.v3.skycell.2146.069.stk.r.unconv.fits |
# | rings.v3.skycell.2146.069.stk.y                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/069/rings.v3.skycell.2146.069.stk.y.unconv.fits |
# | rings.v3.skycell.2146.069.stk.z                      | http://ps1images.stsci.edu/rings.v3.skycell/2146/069/rings.v3.skycell.2146.069.stk.z.unconv.fits |
# | STSCI_PR_2000-23                                     | mast:OPO/product/STSCI_PR_2000-23/STSCI-H-p0023b-f-1497x1517.tif                                 |
# | jw01031-c1005_t014_miri_ch3-long                     | mast:JWST/product/jw01031-c1005_t014_miri_ch3-long_s3d.fits                                      |
# | jw01031-c1005_t014_miri_ch3-medium                   | mast:JWST/product/jw01031-c1005_t014_miri_ch3-medium_s3d.fits                                    |
# | jw01031-c1005_t014_miri_ch3-short                    | mast:JWST/product/jw01031-c1005_t014_miri_ch3-short_s3d.fits                                     |
# | jw01031-c1005_t014_miri_ch4-long                     | mast:JWST/product/jw01031-c1005_t014_miri_ch4-long_s3d.fits                                      |
# | jw01031-c1005_t014_miri_ch4-medium                   | mast:JWST/product/jw01031-c1005_t014_miri_ch4-medium_s3d.fits                                    |
# | jw01031-c1005_t014_miri_ch4-short                    | mast:JWST/product/jw01031-c1005_t014_miri_ch4-short_s3d.fits                                     |
# | jw01031-c1005_t014_miri_ch2-medium                   | mast:JWST/product/jw01031-c1005_t014_miri_ch2-medium_s3d.fits                                    |
# | jw01031-c1005_t014_miri_ch2-long                     | mast:JWST/product/jw01031-c1005_t014_miri_ch2-long_s3d.fits                                      |
# | jw01031-c1005_t014_miri_ch2-short                    | mast:JWST/product/jw01031-c1005_t014_miri_ch2-short_s3d.fits                                     |
# | jw01031-c1005_t014_miri_ch1-medium                   | mast:JWST/product/jw01031-c1005_t014_miri_ch1-medium_s3d.fits                                    |
# | jw01031-c1005_t014_miri_ch1-short                    | mast:JWST/product/jw01031-c1005_t014_miri_ch1-short_s3d.fits                                     |
# | jw01031-c1005_t014_miri_ch1-long                     | mast:JWST/product/jw01031-c1005_t014_miri_ch1-long_s3d.fits                                      |
# | jw01031-o008_t011_miri_f560w                         | mast:JWST/product/jw01031-o008_t011_miri_f560w_i2d.fits                                          |
# | jw01031-o003_t014_miri_f560w                         | mast:JWST/product/jw01031-o003_t014_miri_f560w_i2d.fits                                          |
# | jw01031-o008_t011_miri_ch4-short                     | mast:JWST/product/jw01031-o008_t011_miri_ch4-short_s3d.fits                                      |
# | jw01031-o008_t011_miri_ch4-long                      | mast:JWST/product/jw01031-o008_t011_miri_ch4-long_s3d.fits                                       |
# | jw01031-o008_t011_miri_ch4-medium                    | mast:JWST/product/jw01031-o008_t011_miri_ch4-medium_s3d.fits                                     |
# | jw01031-o008_t011_miri_ch3-medium                    | mast:JWST/product/jw01031-o008_t011_miri_ch3-medium_s3d.fits                                     |
# | jw01031-o008_t011_miri_ch3-long                      | mast:JWST/product/jw01031-o008_t011_miri_ch3-long_s3d.fits                                       |
# | jw01031-o008_t011_miri_ch3-short                     | mast:JWST/product/jw01031-o008_t011_miri_ch3-short_s3d.fits                                      |
# | jw01031-o008_t011_miri_ch2-medium                    | mast:JWST/product/jw01031-o008_t011_miri_ch2-medium_s3d.fits                                     |
# | jw01031-o008_t011_miri_ch2-long                      | mast:JWST/product/jw01031-o008_t011_miri_ch2-long_s3d.fits                                       |
# | jw01031-o008_t011_miri_ch2-short                     | mast:JWST/product/jw01031-o008_t011_miri_ch2-short_s3d.fits                                      |
# | jw01031-o008_t011_miri_ch1-medium                    | mast:JWST/product/jw01031-o008_t011_miri_ch1-medium_s3d.fits                                     |
# | jw01031-o008_t011_miri_ch1-short                     | mast:JWST/product/jw01031-o008_t011_miri_ch1-short_s3d.fits                                      |
# | jw01031-o008_t011_miri_ch1-long                      | mast:JWST/product/jw01031-o008_t011_miri_ch1-long_s3d.fits                                       |
# | lwp02433                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02433.mxhi.gz                            |
# | lwp02434                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02434.mxhi.gz                            |
# | lwp02443                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02443.mxhi.gz                            |
# | lwp02444                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02444.mxhi.gz                            |
# | lwp02445                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02445.mxhi.gz                            |
# | lwp02446                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02446.mxhi.gz                            |
# | lwp02447                                             | http://archive.stsci.edu/missions/iue/data/lwp/02000/lwp02447.mxhi.gz                            |
# | lwp10515                                             | http://archive.stsci.edu/pub/vospectra/iue2/lwp10515mxlo_vo.fits                                 |
# | lwp10551                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10551.mxhi.gz                            |
# | lwp10552                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10552.mxhi.gz                            |
# | lwp10553                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10553.mxhi.gz                            |
# | lwp10554                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10554.mxhi.gz                            |
# | lwp10555                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10555.mxhi.gz                            |
# | lwp10556                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10556.mxhi.gz                            |
# | lwp10557                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10557.mxhi.gz                            |
# | lwp10558                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10558.mxhi.gz                            |
# | lwp10559                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10559.mxhi.gz                            |
# | lwp10560                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10560.mxhi.gz                            |
# | lwp10561                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10561.mxhi.gz                            |
# | lwp10563                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10563.mxhi.gz                            |
# | lwp10564                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10564.mxhi.gz                            |
# | lwp10565                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10565.mxhi.gz                            |
# | lwp10566                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10566.mxhi.gz                            |
# | lwp10567                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10567.mxhi.gz                            |
# | lwp10568                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10568.mxhi.gz                            |
# | lwp10569                                             | http://archive.stsci.edu/missions/iue/data/lwp/10000/lwp10569.mxhi.gz                            |
# +------------------------------------------------------+--------------------------------------------------------------------------------------------------+

# %% [markdown]
# # Скачивание файла по url ссылке
# Изменяйте только mast_uri.
#
# base_url трогать не нужно

# %%
from astroquery.mast import Observations
import requests
from urllib.parse import quote
import os

# 1. Формируем URL для скачивания
mast_uri = "mast:TESS/product/tess2021204101404-s0041-0000000312070919-0212-s_lc.fits"


base_url = "https://mast.stsci.edu/api/v0.1/Download/file?uri="
download_url = base_url + quote(mast_uri)

# 2. Скачиваем файл напрямую
try:
    response = requests.get(download_url, stream=True)
    response.raise_for_status()  # Проверяем ошибки HTTP
    
    filename = os.path.basename(mast_uri.split('/')[-1])
    with open(filename, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    
    print(f"Файл успешно скачан: {filename}")
    print(f"Размер: {os.path.getsize(filename)/1024:.1f} KB")

except Exception as e:
    print(f"Ошибка при скачивании: {str(e)}")
# Out:
# Файл успешно скачан: jw01031-c1005_t014_miri_ch3-long_s3d.fits
# Размер: 45261.6 KB
